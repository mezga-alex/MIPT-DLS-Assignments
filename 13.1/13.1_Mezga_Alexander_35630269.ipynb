# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon May 11 14:26:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Dataset prepared for Pytorch Pipeline

# %%
# !gdown --id 1cV2bDv5h0_wS7fANNdQPWM40hE3PyWls
# !unzip springfield_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: springfield_dataset/train/ned_flanders/pic_1398.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1399.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1400.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1401.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1402.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1403.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1404.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1405.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1406.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1407.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1408.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1409.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1410.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1411.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1412.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1413.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1414.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1415.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1416.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1417.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1418.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1419.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1420.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1421.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1422.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1423.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1424.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1425.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1426.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1427.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1428.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1429.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1430.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1431.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1432.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1433.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1434.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1435.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1436.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1437.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1438.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1439.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1440.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1441.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1442.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1443.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1445.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1446.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1447.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1448.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1449.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1450.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1451.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1452.jpg
#   inflating: springfield_dataset/train/ned_flanders/pic_1453.jpg
#    creating: springfield_dataset/train/nelson_muntz/
#   inflating: springfield_dataset/train/nelson_muntz/pic_0000.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0001.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0002.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0003.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0004.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0007.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0008.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0009.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0010.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0011.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0012.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0013.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0015.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0016.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0017.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0018.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0019.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0020.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0021.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0022.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0023.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0024.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0025.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0027.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0028.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0029.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0030.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0031.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0032.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0033.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0034.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0035.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0036.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0037.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0039.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0040.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0041.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0042.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0043.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0044.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0045.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0046.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0047.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0048.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0050.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0051.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0052.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0053.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0054.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0055.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0056.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0058.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0059.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0060.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0061.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0062.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0063.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0064.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0065.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0066.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0067.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0068.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0070.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0071.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0072.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0073.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0074.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0075.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0076.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0077.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0078.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0079.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0080.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0081.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0083.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0084.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0085.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0086.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0087.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0088.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0089.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0090.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0091.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0092.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0093.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0094.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0095.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0096.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0097.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0098.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0099.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0100.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0102.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0103.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0104.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0105.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0106.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0108.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0109.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0110.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0111.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0112.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0113.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0114.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0115.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0116.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0117.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0118.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0119.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0120.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0121.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0122.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0124.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0125.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0126.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0127.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0128.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0129.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0130.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0131.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0132.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0133.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0134.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0135.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0136.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0138.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0139.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0140.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0141.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0142.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0143.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0144.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0145.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0146.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0148.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0149.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0150.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0151.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0152.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0153.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0154.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0155.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0156.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0157.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0158.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0159.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0160.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0161.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0162.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0163.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0164.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0165.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0166.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0167.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0168.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0169.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0170.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0171.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0172.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0175.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0176.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0177.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0178.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0180.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0181.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0182.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0183.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0184.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0185.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0186.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0187.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0188.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0189.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0190.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0191.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0192.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0193.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0195.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0196.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0197.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0198.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0199.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0200.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0201.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0202.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0203.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0204.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0205.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0206.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0207.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0208.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0209.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0210.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0211.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0212.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0213.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0214.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0215.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0216.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0217.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0218.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0219.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0220.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0221.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0222.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0223.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0224.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0225.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0226.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0227.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0228.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0229.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0230.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0231.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0232.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0233.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0235.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0236.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0237.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0239.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0240.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0241.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0242.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0244.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0245.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0246.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0247.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0248.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0250.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0251.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0252.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0253.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0254.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0255.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0256.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0257.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0258.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0259.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0260.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0261.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0262.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0263.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0265.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0266.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0267.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0268.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0270.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0272.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0273.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0274.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0276.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0277.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0278.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0279.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0280.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0281.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0282.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0284.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0285.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0286.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0288.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0289.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0290.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0291.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0292.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0293.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0294.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0295.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0296.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0297.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0298.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0299.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0300.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0301.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0302.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0303.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0305.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0306.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0308.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0309.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0310.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0311.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0313.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0314.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0315.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0317.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0318.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0319.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0320.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0321.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0323.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0324.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0325.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0326.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0327.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0328.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0329.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0330.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0332.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0333.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0334.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0335.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0336.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0337.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0338.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0339.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0340.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0341.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0342.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0343.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0344.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0345.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0346.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0347.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0348.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0349.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0350.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0351.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0352.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0353.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0354.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0355.jpg
#   inflating: springfield_dataset/train/nelson_muntz/pic_0356.jpg
#    creating: springfield_dataset/train/otto_mann/
#   inflating: springfield_dataset/train/otto_mann/pic_0000.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0001.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0002.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0003.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0004.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0005.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0007.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0008.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0009.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0010.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0011.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0012.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0013.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0015.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0016.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0017.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0018.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0019.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0020.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0021.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0022.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0023.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0024.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0025.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0027.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0028.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0029.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0030.jpg
#   inflating: springfield_dataset/train/otto_mann/pic_0031.jpg
#    creating: springfield_dataset/train/patty_bouvier/
#   inflating: springfield_dataset/train/patty_bouvier/pic_0000.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0001.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0002.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0003.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0004.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0007.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0008.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0009.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0010.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0011.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0012.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0013.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0015.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0016.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0017.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0018.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0019.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0020.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0021.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0022.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0023.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0024.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0025.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0027.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0028.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0029.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0030.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0031.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0032.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0033.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0034.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0035.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0036.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0037.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0039.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0040.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0041.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0042.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0043.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0044.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0045.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0046.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0047.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0048.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0049.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0050.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0051.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0052.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0053.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0054.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0055.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0056.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0058.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0059.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0060.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0061.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0062.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0063.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0064.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0065.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0066.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0067.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0068.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0070.jpg
#   inflating: springfield_dataset/train/patty_bouvier/pic_0071.jpg
#    creating: springfield_dataset/train/principal_skinner/
#   inflating: springfield_dataset/train/principal_skinner/pic_0000.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0001.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0002.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0003.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0004.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0007.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0008.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0009.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0010.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0011.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0012.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0013.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0015.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0016.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0017.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0018.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0019.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0020.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0021.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0022.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0023.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0024.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0025.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0027.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0028.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0029.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0030.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0031.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0032.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0033.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0034.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0035.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0036.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0037.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0039.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0040.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0041.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0042.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0043.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0044.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0045.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0046.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0047.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0048.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0050.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0051.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0052.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0053.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0054.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0055.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0056.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0058.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0059.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0060.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0061.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0062.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0063.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0064.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0065.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0066.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0067.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0068.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0070.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0071.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0072.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0073.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0074.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0075.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0076.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0077.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0078.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0079.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0080.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0081.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0083.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0084.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0085.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0086.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0087.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0088.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0089.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0090.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0091.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0092.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0093.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0094.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0095.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0096.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0097.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0098.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0099.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0100.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0102.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0103.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0104.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0105.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0106.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0108.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0109.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0110.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0111.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0112.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0113.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0114.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0115.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0116.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0117.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0118.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0119.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0120.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0121.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0122.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0124.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0125.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0126.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0127.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0128.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0129.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0130.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0131.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0132.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0133.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0134.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0135.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0136.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0138.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0139.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0140.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0141.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0142.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0143.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0144.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0145.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0146.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0148.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0149.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0150.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0151.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0152.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0153.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0154.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0155.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0156.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0157.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0158.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0159.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0160.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0161.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0162.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0163.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0164.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0165.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0166.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0167.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0168.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0169.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0170.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0171.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0172.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0175.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0176.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0177.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0178.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0180.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0181.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0182.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0183.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0184.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0185.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0186.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0187.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0188.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0189.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0190.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0191.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0192.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0193.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0195.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0196.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0197.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0198.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0199.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0200.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0201.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0202.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0203.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0204.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0205.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0206.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0207.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0208.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0209.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0210.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0211.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0212.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0213.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0214.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0215.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0216.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0217.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0218.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0219.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0220.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0221.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0222.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0223.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0224.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0225.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0226.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0227.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0228.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0229.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0230.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0231.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0232.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0233.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0235.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0236.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0237.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0239.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0240.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0241.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0242.jpg
#   inflating: springfield_dataset/train/principal_skinner/pic_0244.jpg
# ...
#   inflating: springfield_dataset/val/principal_skinner/pic_0331.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0357.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0371.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0378.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0400.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0413.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0424.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0430.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0433.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0442.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0466.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0478.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0486.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0498.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0502.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0513.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0527.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0537.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0538.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0543.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0549.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0552.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0557.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0565.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0573.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0578.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0580.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0600.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0617.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0633.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0635.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0646.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0658.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0661.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0663.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0670.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0672.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0676.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0682.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0686.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0687.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0704.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0716.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0720.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0731.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0742.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0747.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0749.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0761.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0781.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0786.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0788.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0789.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0791.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0811.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0824.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0825.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0828.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0831.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0838.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0839.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0855.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0871.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0884.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0885.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0912.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0914.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0939.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0962.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0964.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0970.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0989.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_0991.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1025.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1027.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1035.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1042.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1053.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1070.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1071.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1090.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1092.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1098.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1108.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1146.jpg
#   inflating: springfield_dataset/val/principal_skinner/pic_1192.jpg
#    creating: springfield_dataset/val/professor_john_frink/
#   inflating: springfield_dataset/val/professor_john_frink/pic_0005.jpg
#   inflating: springfield_dataset/val/professor_john_frink/pic_0006.jpg
#   inflating: springfield_dataset/val/professor_john_frink/pic_0014.jpg
#   inflating: springfield_dataset/val/professor_john_frink/pic_0026.jpg
#   inflating: springfield_dataset/val/professor_john_frink/pic_0038.jpg
#   inflating: springfield_dataset/val/professor_john_frink/pic_0057.jpg
#    creating: springfield_dataset/val/rainier_wolfcastle/
#   inflating: springfield_dataset/val/rainier_wolfcastle/pic_0006.jpg
#   inflating: springfield_dataset/val/rainier_wolfcastle/pic_0014.jpg
#   inflating: springfield_dataset/val/rainier_wolfcastle/pic_0026.jpg
#   inflating: springfield_dataset/val/rainier_wolfcastle/pic_0038.jpg
#    creating: springfield_dataset/val/ralph_wiggum/
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0005.jpg
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0006.jpg
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0014.jpg
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0026.jpg
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0038.jpg
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0057.jpg
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0069.jpg
#   inflating: springfield_dataset/val/ralph_wiggum/pic_0082.jpg
#    creating: springfield_dataset/val/selma_bouvier/
#   inflating: springfield_dataset/val/selma_bouvier/pic_0005.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0006.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0014.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0026.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0038.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0049.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0057.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0069.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0082.jpg
#   inflating: springfield_dataset/val/selma_bouvier/pic_0101.jpg
#    creating: springfield_dataset/val/sideshow_bob/
#   inflating: springfield_dataset/val/sideshow_bob/pic_0005.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0006.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0014.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0026.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0038.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0057.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0069.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0082.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0101.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0107.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0123.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0137.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0147.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0173.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0174.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0179.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0194.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0234.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0243.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0249.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0264.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0269.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0271.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0275.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0283.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0287.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0304.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0312.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0331.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0371.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0378.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0400.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0413.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0424.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0430.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0442.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0466.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0478.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0486.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0498.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0502.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0513.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0527.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0537.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0538.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0543.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0549.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0552.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0557.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0565.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0573.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0578.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0580.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0600.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0617.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0633.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0635.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0646.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0658.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0661.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0663.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0672.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0676.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0682.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0686.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0687.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0716.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0720.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0731.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0742.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0747.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0749.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0761.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0781.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0786.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0788.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0789.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0791.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0811.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0824.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0825.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0828.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0831.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0838.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0839.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0855.jpg
#   inflating: springfield_dataset/val/sideshow_bob/pic_0871.jpg
#    creating: springfield_dataset/val/sideshow_mel/
#   inflating: springfield_dataset/val/sideshow_mel/pic_0006.jpg
#   inflating: springfield_dataset/val/sideshow_mel/pic_0014.jpg
#   inflating: springfield_dataset/val/sideshow_mel/pic_0026.jpg
#   inflating: springfield_dataset/val/sideshow_mel/pic_0038.jpg
#    creating: springfield_dataset/val/snake_jailbird/
#   inflating: springfield_dataset/val/snake_jailbird/pic_0005.jpg
#   inflating: springfield_dataset/val/snake_jailbird/pic_0006.jpg
#   inflating: springfield_dataset/val/snake_jailbird/pic_0014.jpg
#   inflating: springfield_dataset/val/snake_jailbird/pic_0026.jpg
#   inflating: springfield_dataset/val/snake_jailbird/pic_0038.jpg
#    creating: springfield_dataset/val/troy_mcclure/
#   inflating: springfield_dataset/val/troy_mcclure/pic_0006.jpg
#    creating: springfield_dataset/val/waylon_smithers/
#   inflating: springfield_dataset/val/waylon_smithers/pic_0005.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0006.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0014.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0021.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0026.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0038.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0049.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0057.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0069.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0082.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0101.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0107.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0123.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0137.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0147.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0173.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0174.jpg
#   inflating: springfield_dataset/val/waylon_smithers/pic_0179.jpg

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
# !ls springfield_dataset/
# Out:
# characters_illustration.png  sample_submission.csv  train
# make_val.py		     testset		    val

# %% [markdown]
# Create Training and Validation sets.
#
# Prepare input images.

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

data_dir = 'springfield_dataset/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print(dataloaders)
print(dataset_sizes)
print(class_names)
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x7fbfd588d6a0>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x7fbf6e6b3f28>}
# {'train': 18857, 'val': 2076}
# ['abraham_grampa_simpson', 'agnes_skinner', 'apu_nahasapeemapetilon', 'barney_gumble', 'bart_simpson', 'carl_carlson', 'charles_montgomery_burns', 'chief_wiggum', 'cletus_spuckler', 'comic_book_guy', 'disco_stu', 'edna_krabappel', 'fat_tony', 'gil', 'groundskeeper_willie', 'homer_simpson', 'kent_brockman', 'krusty_the_clown', 'lenny_leonard', 'lionel_hutz', 'lisa_simpson', 'maggie_simpson', 'marge_simpson', 'martin_prince', 'mayor_quimby', 'milhouse_van_houten', 'miss_hoover', 'moe_szyslak', 'ned_flanders', 'nelson_muntz', 'otto_mann', 'patty_bouvier', 'principal_skinner', 'professor_john_frink', 'rainier_wolfcastle', 'ralph_wiggum', 'selma_bouvier', 'sideshow_bob', 'sideshow_mel', 'snake_jailbird', 'troy_mcclure', 'waylon_smithers']

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# Training function of the model with the given parameters

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ***************************
# **TRAIN**
#
# Optional step, you can **skip** because the next step contains trained weights.

# %% [markdown]
# Transfer learning was used.
#
# Pretrained **resnext50_32x4d** has been trained for 10 epochs. The best parameters were saved in the model.
#
# Parameters will be restored in the next step.

# %%
# model_ft = models.resnet18(pretrained=True)
import torchvision.models as models
model_ft = models.resnext50_32x4d(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 42)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to /root/.cache/torch/checkpoints/resnext50_32x4d-7cdf4587.pth
# HBox(children=(FloatProgress(value=0.0, max=100441675.0), HTML(value='')))

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=10)

# %% [markdown]
# ***************************
#
# **Recover the weight** and initialize the new resnext50_32x4d model with them.

# %%
# Download parameters
# !gdown --id 1RB9RbRt1_VlLTuKLaLHtTEXhyn_NRoo7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RB9RbRt1_VlLTuKLaLHtTEXhyn_NRoo7
# To: /content/resnext.pt
# 92.6MB [00:00, 223MB/s]

# %%
# Initialize a new model with the best parameters restored
model_ft = models.resnext50_32x4d()
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 42)
model_ft = model_ft.to(device)

path = F"/content/resnext.pt" 
model_ft.load_state_dict(torch.load(path))
model_ft.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=42, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# ***************************
# Try to improve current results.
#
# This step **didn't bring improvement**. **Skip**

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.3186 Acc: 0.9148
# val Loss: 0.0428 Acc: 0.9899
#
# Epoch 1/24
# ----------
# train Loss: 0.3194 Acc: 0.9140
# val Loss: 0.0545 Acc: 0.9851
#
# Epoch 2/24
# ----------
# train Loss: 0.2957 Acc: 0.9226
# val Loss: 0.0402 Acc: 0.9913
#
# Epoch 3/24
# ----------
# train Loss: 0.3056 Acc: 0.9185
# val Loss: 0.0459 Acc: 0.9899
#
# Epoch 4/24
# ----------
# train Loss: 0.2778 Acc: 0.9247
# val Loss: 0.0543 Acc: 0.9851
#
# Epoch 5/24
# ----------
# train Loss: 0.2747 Acc: 0.9260
# val Loss: 0.0526 Acc: 0.9865
#
# Epoch 6/24
# ----------
# train Loss: 0.2592 Acc: 0.9287
# val Loss: 0.0462 Acc: 0.9880
#
# Epoch 7/24
# ----------
# train Loss: 0.2351 Acc: 0.9359
# val Loss: 0.0391 Acc: 0.9894
#
# Epoch 8/24
# ----------
# train Loss: 0.2253 Acc: 0.9410
# val Loss: 0.0391 Acc: 0.9894
#
# Epoch 9/24
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-214-cc88ea5f8bd3> in <module>()
#       1 model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
# ----> 2                        num_epochs=25)
#
# <ipython-input-132-1a5d4f162548> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      36                     # backward + optimize only if in training phase
#      37                     if phase == 'train':
# ---> 38                         loss.backward()
#      39                         optimizer.step()
#      40
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:

# %% [markdown]
# Save the best weights. **Not necessary**

# %%
model_save_name = 'resnext.pt'
path = F"/content/drive/My Drive/{model_save_name}"
torch.save(model_ft.state_dict(), path)

# %% [markdown]
# ***************************
#
# **Validation**

# %%
# Iterate over data.
val_preds = np.array([], dtype='int32')
val_labels = np.array([], dtype='int32')
running_corrects = 0

for inputs, labels in dataloaders['val']:
    inputs = inputs.to(device)
    labels = labels.to(device)
   
    outputs = model_ft(inputs)
    _, preds = torch.max(outputs, 1)

    # statistics
    running_corrects += torch.sum(preds == labels.data)
    
    preds = preds.cpu().numpy()
    labels = labels.cpu().numpy()

    val_preds = np.concatenate((val_preds, preds), axis=None)
    val_labels = np.concatenate((val_labels, labels), axis=None)

# %%
print(val_preds)
print(val_labels)
(unique, counts) = np.unique(val_preds, return_counts=True)
frequencies = np.asarray((unique, counts)).T
print(frequencies)
# Out:
# [16 15  2 ...  7 37  6]
# [16 15  2 ...  7 37  6]
# [[  0  91]
#  [  1   4]
#  [  2  61]
#  [  3  10]
#  [  4 134]
#  [  5   9]
#  [  6 119]
#  [  7  97]
#  [  8   4]
#  [  9  46]
#  [ 11  44]
#  [ 12   2]
#  [ 13   2]
#  [ 14  11]
#  [ 15 226]
#  [ 16  49]
#  [ 17 120]
#  [ 18  31]
#  [ 20 134]
#  [ 21  12]
#  [ 22 128]
#  [ 23   9]
#  [ 24  25]
#  [ 25 109]
#  [ 26   1]
#  [ 27 149]
#  [ 28 146]
#  [ 29  34]
#  [ 30   3]
#  [ 31   7]
#  [ 32 118]
#  [ 33   6]
#  [ 34   3]
#  [ 35   8]
#  [ 36  10]
#  [ 37  87]
#  [ 38   4]
#  [ 39   5]
#  [ 41  18]]

# %%
from sklearn.metrics import f1_score
print(f1_score(val_labels, val_preds, average='micro'))
print(f1_score(val_labels, val_preds, average='macro'))
print(f1_score(val_labels, val_preds, average='weighted'))
# Out:
# 0.9894026974951831
# 0.9086346522934735
# 0.988714637298817

# %% [markdown]
# ***************************
#
# **Test**
#
# In order not to take risks with the final results, the pipeline DLS is used

# %%
# Download label_encoder
# !gdown --id 15UI2ogJbAP2u04AKKj8byqqv1SPCbbGi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15UI2ogJbAP2u04AKKj8byqqv1SPCbbGi
# To: /content/label_encoder.pkl
# 100% 4.30k/4.30k [00:00<00:00, 7.42MB/s]

# %%
import pickle
from pathlib import Path

TEST_DIR = Path('/content/springfield_dataset/testset/testset')
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))
DATA_MODES = ['train', 'val', 'test']
RESCALE_SIZE = 224

label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

# %%
print(len(test_files))
# Out:
# 991

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from PIL import Image

class SimpsonsDataset(Dataset):
    """
    Датасет с картинками, который паралельно подгружает их из папок
    производит скалирование и превращение в торчевые тензоры
    """
    def __init__(self, files, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode

        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.len_ = len(self.files)
     
        self.label_encoder = LabelEncoder()

        if self.mode != 'test':
            self.labels = [path.parent.name for path in self.files]
            self.label_encoder.fit(self.labels)

            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file)
                      
    def __len__(self):
        return self.len_
      
    def load_sample(self, file):
        image = Image.open(file)
        image.load()
        return image
  
    def __getitem__(self, index):
        # для преобразования изображений в тензоры PyTorch и нормализации входа
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
        ])
        x = self.load_sample(self.files[index])
        x = self._prepare_sample(x)
        x = np.array(x / 255, dtype='float32')
        x = transform(x)
        if self.mode == 'test':
            return x
        else:
            label = self.labels[index]
            label_id = self.label_encoder.transform([label])
            y = label_id.item()
            return x, y
        
    def _prepare_sample(self, image):
        image = image.resize((RESCALE_SIZE, RESCALE_SIZE))
        return np.array(image)

# %%
def predict(model, test_loader):
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(device)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %% [markdown]
# Make predictions
#
# **The final Test Result**: 0.99468
#
# **Kaggle Nickname**: Mezga_Alexander_35630269

# %%
test_dataset = SimpsonsDataset(test_files, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)

# %%
probs = predict(model_ft, test_loader)

# %%
preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))
test_filenames = [path.name for path in test_dataset.files]

# %% [markdown]
# Create submission and save to the Drive

# %%
import pandas as pd
# my_submit = pd.read_csv("gdrive/My Drive/simpsons/data/labels.csv")
my_submit = pd.DataFrame({'Id': test_filenames, 'Expected': preds})
my_submit.head()
my_submit.to_csv('/content/drive/My Drive/DLS_Hometask/resnet_baseline_2.csv', index=False)
